# %% [markdown]
# <a href="https://colab.research.google.com/github/princekrsingh780-gif/DMAV-lab/blob/main/Missing_values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

data = np.array([1, 2, np.nan, 4, np.nan])

df = pd.DataFrame(data, columns=["Values"])

print(df.isna())
# Out:
#    Values
# 0   False
# 1   False
# 2    True
# 3   False
# 4    True
